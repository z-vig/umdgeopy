# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
sys.path.append(Path.cwd().__str__())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import module1

# %%
avg = module1.plot_random(500)
print(f"Average: {avg}")
# Out:
# TEST
# Average: 2.9568837983451415
